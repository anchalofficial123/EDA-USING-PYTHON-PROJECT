# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\ancha\Downloads\Customer Churn.csv")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# # replacing blanks with 0 as tenture is 0 ams and no total charges are recorded

# %%
df["TotalCharges"]= df ['TotalCharges'].replace(" ","0")
df["TotalCharges"]= df['TotalCharges'].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df["customerID"].duplicated().sum()
# Out:
# 0

# %%
def conv(value):
    if value==1:
        return "yes"
    else:
        return "no"
df ["SeniorCitizen" ] = df["SeniorCitizen"].apply(conv)

# %% [markdown]
# # converted 0 and 1 values of senior citizen to yes/no to make it easier to understand

# %%
ax = sns.countplot(x = 'Churn',data=df)

ax.bar_label(ax.containers[0])
plt.title
plt.show()

# %%
plt.figure(figsize=(3,4))
gb=df.groupby('Churn').agg({'Churn':"count"})

plt.pie(gb['Churn'],labels=gb.index,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # from the given we can conclude that 26.54% of our customer have churned out
# # not lets explore the reason behind it

# %%
plt.figure(figsize = (3,3))
sns.countplot(x = "SeniorCitizen",data = df, hue ="Churn") 
plt.title("churn by SeniorCitizen")
plt.show()

# %%
plt.figure(figsize = (2,3))
sns.countplot(x = "SeniorCitizen",data = df) 
ax.bar_label
plt.title("churn of customer bye  SeniorCitizen")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {'SeniorCitizen': [0, 1, 0, 1, 1, 0, 1, 0, 0, 1],
        'Churn': ['Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes']}
df = pd.DataFrame(data)


churn_by_senior = pd.crosstab(df['SeniorCitizen'], df['Churn'], normalize='index') * 100


churn_by_senior.plot(kind='bar', stacked=True, figsize=(4, 5), color=['skyblue', 'orange'])


plt.title("Churn by Senior Citizen (%)")
plt.xlabel("Senior Citizen")
plt.ylabel("Percentage")

for index, row in churn_by_senior.iterrows():
    for i, value in enumerate(row):
        plt.text(i + index - 0.1, value / 2 + row[:i].sum(), f'{value:.1f}%', ha='center')

plt.show()

# %%
df=pd.read_csv(r"C:\Users\ancha\Downloads\Customer Churn.csv")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
print(df.columns)
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
plt.figure(figsize=(9,4))
sns.histplot(x="tenure",data=df,bins=50,hue="Churn")
plt.show()

# %% [markdown]
# # people who have used our services for a long time styed and people who have used services for 1 or 2 month

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 4))  
ax = sns.countplot(x='Contract', data=df,hue="Churn")
ax.bar_label(ax.containers[0])  
plt.title("Churn of Customers by Contract", fontsize=14)  
plt.xlabel("Contract", fontsize=12)  
plt.ylabel("Count", fontsize=12) 
plt.ylim(0, 4500)  
plt.show()

# %%
# people who have moth to month contract are likely to churn then from those who have 1 or 2 years or contract

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
columns = [
    'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 12))
fig.suptitle('Countplots for Telecom Service Usage', fontsize=16)

axes = axes.flatten()

for i, column in enumerate(columns):
    sns.countplot(data=df, x=column, ax=axes[i], hue=column, palette='viridis', legend=False)
    axes[i].set_title(column)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Count')

plt.tight_layout()
plt.subplots_adjust(top=0.92)  

plt.show()

# %%
plt.figure(figsize=(5, 4))  
ax = sns.countplot(x='OnlineSecurity', data=df,hue="Churn")
ax.bar_label(ax.containers[0])  
plt.title("Churn of Customers by OnlineSecurity", fontsize=14)  
plt.xlabel("Contract", fontsize=12)  
plt.ylabel("Count", fontsize=12) 

plt.ylim(0, 4500)
# Out:
# (0.0, 4500.0)

# %% [markdown]
# It includes Python code for loading and analyzing a dataset on customer churn, likely using libraries such as pandas, numpy, matplotlib, and seaborn.
#
# To create a summary of the analysis, I'll look for comments, markdown cells, or specific code segments that indicate the analytical steps and results documented in the notebook. I'll process the notebook content and extract key insights for you. ​​
#
# The notebook includes both data processing steps and specific analyses related to customer churn. Here’s a summary based on the initial content:
#
# Data Preprocessing:
#
# Blank values in the tenure column were replaced with 0, especially where total charges were not recorded.
# For clarity, the values in the SeniorCitizen column were converted from 0 and 1 to Yes/No.
# Customer Churn Analysis:
#
# Initial analysis revealed that approximately 26.54% of customers have churned.
# The next steps in the notebook focus on exploring potential reasons behind customer churn.
# Would you like further analysis from specific sections, or a focus on visual insights, statistical measures, or correlations found in the dataset? ​​
